# %%
import pandas as pd
import os

# Diretório dos arquivos Excel
diretorio = (r"K:\Python\Arquivos\Origem\arquivos_excel\Consolidar")

# Lista para armazenar os dados dos arquivos
dados = []

# Iterar sobre os arquivos Excel no diretório
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.xlsx'):
        caminho_arquivo = os.path.join(diretorio, arquivo)
        df = pd.read_excel(caminho_arquivo)
        dados.append(df)

# Consolidar os dados em um único DataFrame
consolidado = pd.concat(dados)
consolidado
# Out:
#           Data  Id Venda  IdCategoria    Categoria  IdPais      Pais  \
# 0   2021-04-02       573            1         Moda     636  Alemanha
# 1   2021-04-02       599            4   Acessórios     637    França
# 2   2021-04-02      1125            1         Moda     636  Alemanha
# 3   2021-04-02      1151            4   Acessórios     637    França
# 4   2021-04-06       394            5  Automitivos     639       USA
# ..         ...       ...          ...          ...     ...       ...
# 264 2023-06-08        65            2     Calçados     636  Alemanha
# 265 2023-06-08       559            1         Moda     639       USA
# 266 2023-06-08      1111            1         Moda     639       USA
# 267 2023-06-04        37            3  Eletrônicos     639       USA
# 268 2023-06-04       486            3  Eletrônicos     639       USA
#
#      idProduto       Produto  Custo fabricacao  Unidades Vendidas  \
# 0           15        Shorts                10               1033
# 1           12       Relogio               120                739
# 2           15        Shorts                10                790
# 3           12       Relogio               120                953
# 4            8  Limpa vidros               250                290
# ..         ...           ...               ...                ...
# 264          1         Botas                 3                448
# 265          5      Camiseta               120                397
# 266          5      Camiseta               120                532
# 267         16     Smartfone               120                898
# 268          6       Desktop               260                361
#
#      Preco venda  Vendas total  Descontos
# 0             20         20660   3674.400
# 1             15         11085   7795.125
# 2             20         15800   3674.400
# 3             15         14295   7795.125
# 4            300         87000  19392.000
# ..           ...           ...        ...
# 264           12          5376     91.920
# 265          350        138950  41412.000
# 266          350        186200  41412.000
# 267          125        112250      0.000
# 268          125         45125   7237.500
#
# [332 rows x 13 columns]
