# %% [markdown]
# sqlalchemy - SQL Server
#
#
# Documentação geral
# https://docs.sqlalchemy.org/en/20/core/engines.html
#
# Documentação SQL Server
# https://docs.sqlalchemy.org/en/20/core/engines.html#microsoft-sql-server

# %% [markdown]
#   Exemplo conexão String SQL Server
#
#   f'mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server'

# %%
'''
#pip install sqlalchemy

#Tipos diferentes de conectores
#String personalizada inserir /?odbc_connect=

# pyodbc = pip install pyodbc  ou pip install --upgrade pyodbc 
engine = create_engine("mssql+pyodbc://scott:tiger@mydsn")

Alterar na conexão
/?odbc_connect= 


'''

# %%
#Exemplo
import pandas as pd
from sqlalchemy import create_engine

server = 'EDMILSON\MSSQLSERVER01'
database = 'AdventureWorksDW2019' 
username = 'sa'
password = 123456
conexaoDB = ('DRIVER={ODBC Driver 17 for SQL Server};'
                      f'SERVER={server};'
                      f'DATABASE={database};'
                      'Trusted_Connection=yes;' #conexão usuario do windows
                      #f'UID={username};'
                      #f'PWD={password};'                      
                      )

engine = create_engine(f'mssql+pyodbc:///?odbc_connect={conexaoDB}')

# %%
import pandas as pd
from sqlalchemy import create_engine

conexaoDB = ('DRIVER={ODBC Driver 17 for SQL Server};''SERVER=EDMILSON\MSSQLSERVER01;''DATABASE=AdventureWorksDW2019;''Trusted_Connection=yes;')
engine = create_engine(f'mssql+pyodbc:///?odbc_connect={conexaoDB}')

query = '''
SELECT * FROM [AdventureWorksDW2019].[dbo].[DimProduct]
'''

df = pd.read_sql_query(query, engine)

# Exiba  DataFrame
engine.dispose()
df.head()
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
# 1           2             BA-8327                    NaN
# 2           3             BE-2349                    NaN
# 3           4             BE-2908                    NaN
# 4           5             BL-2036                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                  None                None        Adjustable Race
# 1                  None                None           Bearing Ball
# 2                  None                None        BB Ball Bearing
# 3                  None                None  Headset Ball Bearings
# 4                  None                None                  Blade
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN              False  ...
# ...

# %%
df.to_excel('produto.xlsx', index=False)
