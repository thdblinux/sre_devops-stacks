# %%
from sqlalchemy import create_engine,VARCHAR,NUMERIC,INTEGER,DATE,DATETIME,String
import pandas as pd

# %%
#Conexão com a Origem (Postgre)
eng_postgree = create_engine('postgresql://postgres:12345@localhost:5432/python')

query = """
select 
id
,dt_ocorrencia
,uf
,regiao
,classificacao_da_ocorrencia
from public.anac_mapeamento

"""
df=pd.read_sql_query(query,eng_postgree )

# %%
df.head(15)
# Out:
#       id dt_ocorrencia             uf        regiao  \
# 0   7762    2018-03-21             SP       Sudeste
# 1   7759    2018-03-14             MG       Sudeste
# 2   7758    2018-01-26             GO  Centro-Oeste
# 3   7758    2018-01-26             GO  Centro-Oeste
# 4   7757    2018-03-18             RS           Sul
# 5   5552    2009-07-07             PR           Sul
# 6   5118    2006-10-13             ES       Sudeste
# 7   7756    2018-03-18             PE      Nordeste
# 8   7755    2018-03-18             AL      Nordeste
# 9   7754    2018-03-17             SP       Sudeste
# 10  7754    2018-03-17             SP       Sudeste
# 11  7753    2018-03-16             SP       Sudeste
# 12  5387    2002-08-20  Indeterminado          None
# 13  5665    2002-11-20  Indeterminado          None
# 14  7752    2018-03-16             SP       Sudeste
#
#    classificacao_da_ocorrencia
# 0                    Incidente
# 1                     Acidente
# 2                     Acidente
# 3                     Acidente
# 4              Incidente Grave
# 5                     Acidente
# 6                     Acidente
# 7              Incidente Grave
# 8              Incidente Grave
# 9              Incidente Grave
# 10             Incidente Grave
# 11                    Acidente
# 12                    Acidente
# 13                    Acidente
# 14                   Incidente

# %%
#Conexão de Destino (MySQL)
eng_mysql = create_engine("mysql+mysqldb://root:12345@localhost/python")

tabela_destino='anac_origem_potsgre'

tipo_coluna={
    'id':INTEGER,
    'dt_ocorrencia': DATE, 
    'uf': VARCHAR(15),
    'regiao': VARCHAR(15), 
    'classificacao_da_ocorrencia': VARCHAR(30)
     
    }


df.to_sql(name=tabela_destino, con=eng_mysql, if_exists='replace', dtype= tipo_coluna, index=False    )
# Out:
# 13011

# %%
eng_postgree.dispose()
eng_mysql.dispose()
