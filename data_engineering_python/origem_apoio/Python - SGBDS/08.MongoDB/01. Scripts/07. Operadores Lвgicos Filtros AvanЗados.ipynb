# %%
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)  

client = MongoClient('mongodb+srv://user_aula:Aula.12345@clusteraula.ubzchn7.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

filter={'$and':[{'UF':'MG'},{'Classificacao_da_Ocorrência':'Acidente'}]}
columns ={'Numero_da_Ocorrencia':1,'Classificacao_da_Ocorrência':1,'UF':1,'PSSO':1}

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(5)
# Out:
#                         _id Numero_da_Ocorrencia Classificacao_da_Ocorrência  \
# 0  65fb1650b5171ca17cd7231f                 7759                    Acidente
# 1  65fb1650b5171ca17cd72336                 7516                    Acidente
# 2  65fb1650b5171ca17cd7233f                 7511                    Acidente
# 3  65fb1650b5171ca17cd723a7                 7208                    Acidente
# 4  65fb1650b5171ca17cd72407                 7703                    Acidente
#
#    UF        PSSO
# 0  MG  verdadeiro
# 1  MG       falso
# 2  MG  verdadeiro
# 3  MG  verdadeiro
# 4  MG  verdadeiro

# %%
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)  

client = MongoClient('mongodb+srv://user_aula:Aula.12345@clusteraula.ubzchn7.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

filter={'$or':[{'UF':'GO'},{'PSSO':'verdadeiro'}]}
columns ={'Numero_da_Ocorrencia':1,'Classificacao_da_Ocorrência':1,'UF':1,'PSSO':1}

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(35)
# Out:
#                          _id Numero_da_Ocorrencia Classificacao_da_Ocorrência  \
# 0   65fb1650b5171ca17cd7231e                 7762                   Incidente
# 1   65fb1650b5171ca17cd7231f                 7759                    Acidente
# 2   65fb1650b5171ca17cd72320                 7758                    Acidente
# 3   65fb1650b5171ca17cd72321                 7758                    Acidente
# 4   65fb1650b5171ca17cd72322                 7757             Incidente Grave
# 5   65fb1650b5171ca17cd72324                 5118                    Acidente
# 6   65fb1650b5171ca17cd72327                 7754             Incidente Grave
# 7   65fb1650b5171ca17cd72328                 7754             Incidente Grave
# 8   65fb1650b5171ca17cd72329                 7753                    Acidente
# 9   65fb1650b5171ca17cd7232b                 5665                    Acidente
# 10  65fb1650b5171ca17cd7232d                 7526                   Incidente
# ...
