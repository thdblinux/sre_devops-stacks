# %%
#Selecionando Colunas 
from pymongo import MongoClient
client = MongoClient('mongodb+srv://user_aula:Aula.12345@clusteraula.ubzchn7.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

# 'coluna':0 tirar a coluna do resultado ,'coluna':1 = escolher colunas para aparecer no resultado
# Obs: misturar 0 e 1  tem que esolher somente uma opção  

filter={'UF': 'SP'}
#columns = {'Numero_da_Ocorrencia':0,'Numero_da_Ficha':0,'Operador_Padronizado':0}  # metodos exclusivos
columns = { 'Numero_da_Ocorrencia':1,'Numero_da_Ficha':1,'Classificacao_da_Ocorrência':1,
           'Classificacao_da_Ocorrência':1,'Data_da_Ocorrencia':1,'UF':1,'Regiao':1}   # metodos inclusivo

for doc in colletion.find(filter,columns):
    print(doc)
# Out:
# {'_id': ObjectId('65fb1650b5171ca17cd7231e'), 'Numero_da_Ocorrencia': '7762', 'Numero_da_Ficha': '201803231711488', 'Classificacao_da_Ocorrência': 'Incidente', 'Data_da_Ocorrencia': '2018-03-21', 'UF': 'SP', 'Regiao': 'Sudeste'}
# {'_id': ObjectId('65fb1650b5171ca17cd72327'), 'Numero_da_Ocorrencia': '7754', 'Numero_da_Ficha': '201803182255192', 'Classificacao_da_Ocorrência': 'Incidente Grave', 'Data_da_Ocorrencia': '2018-03-17', 'UF': 'SP', 'Regiao': 'Sudeste'}
# {'_id': ObjectId('65fb1650b5171ca17cd72328'), 'Numero_da_Ocorrencia': '7754', 'Numero_da_Ficha': '201803182255192', 'Classificacao_da_Ocorrência': 'Incidente Grave', 'Data_da_Ocorrencia': '2018-03-17', 'UF': 'SP', 'Regiao': 'Sudeste'}
# {'_id': ObjectId('65fb1650b5171ca17cd72329'), 'Numero_da_Ocorrencia': '7753', 'Numero_da_Ficha': 'PT-UGA 16MAR2018 13H00 SERIPA4', 'Classificacao_da_Ocorrência': 'Acidente', 'Data_da_Ocorrencia': '2018-03-16', 'UF': 'SP', 'Regiao': 'Sudeste'}
# ...
