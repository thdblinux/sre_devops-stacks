# %% [markdown]
# Documentação Json Normalize
#
# https://pandas.pydata.org/docs/dev/reference/api/pandas.json_normalize.html

# %%
#Selecionando Colunas 
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)   # Mostrar todas as colunas

client = MongoClient('mongodb+srv://user_aula:Aula.12345@clusteraula.ubzchn7.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('clientes')

filter={}
columns ={}

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(10)
# Out:
#                         _id      nome  idade sexo                    email  \
# 0  65f8f80f5e61bc1671fba8f7  Edmilson     18    M                      NaN
# 1  65f8faa5777ba54f79cc4e1a    Marcos     25    M                      NaN
# 2  65f8faa5777ba54f79cc4e1c     Julio     37  NaN                      NaN
# 3  65f8faa5777ba54f79cc4e1b   Mariana     65    F     mariana@teste.com.br
# 4  65fb06726fd9895365e989ed    Lilian     25    F   lilian@teste222.com.br
# 5  65fb0957c4201d8f47104ce0   Matheus     45    M  Matheus@teste222.com.br
# 6  65fb0957c4201d8f47104ce1    Matias     55    M   Matias@teste222.com.br
# 7  65fb09a61ff47d32f0695477   Matheus     45    M  Matheus@teste222.com.br
# 8  65fb09a61ff47d32f0695478    Matias     55    M   Matias@teste222.com.br
#
#                                             endereco cores_preferidas  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# ...

# %%
df_tabela= pd.concat([ df.drop('endereco',axis=1) , pd.json_normalize(df['endereco'])], axis=1  )
df_tabela.head(30)
# Out:
#                         _id      nome  idade sexo                    email  \
# 0  65f8f80f5e61bc1671fba8f7  Edmilson     18    M                      NaN
# 1  65f8faa5777ba54f79cc4e1a    Marcos     25    M                      NaN
# 2  65f8faa5777ba54f79cc4e1c     Julio     37  NaN                      NaN
# 3  65f8faa5777ba54f79cc4e1b   Mariana     65    F     mariana@teste.com.br
# 4  65fb06726fd9895365e989ed    Lilian     25    F   lilian@teste222.com.br
# 5  65fb0957c4201d8f47104ce0   Matheus     45    M  Matheus@teste222.com.br
# 6  65fb0957c4201d8f47104ce1    Matias     55    M   Matias@teste222.com.br
# 7  65fb09a61ff47d32f0695477   Matheus     45    M  Matheus@teste222.com.br
# 8  65fb09a61ff47d32f0695478    Matias     55    M   Matias@teste222.com.br
#
#   cores_preferidas     lista_numeros     rua  numero completomento
# 0              NaN               NaN     NaN     NaN           NaN
# 1              NaN               NaN     NaN     NaN           NaN
# ...
