# %%
#Selecionando Colunas 
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)   # Mostrar todas as colunas

client = MongoClient('mongodb+srv://user_aula:Aula.12345@clusteraula.ubzchn7.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

# 'coluna':0 tirar a coluna do resultado ,'coluna':1 = escolher colunas para aparecer no resultado
# Obs: misturar 0 e 1  tem que esolher somente uma opção  

filter={'UF': 'MG'}
#columns = {'Numero_da_Ocorrencia':0,'Numero_da_Ficha':0,'Operador_Padronizado':0}  # metodos exclusivos
#columns = { 'Numero_da_Ocorrencia':1,'Numero_da_Ficha':1,'Classificacao_da_Ocorrência':1,'Classificacao_da_Ocorrência':1,'Data_da_Ocorrencia':1,'UF':1,'Regiao':1}   # metodos inclusivo
columns ={} #todas colunas 

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(3)
# Out:
#                         _id Numero_da_Ocorrencia  Numero_da_Ficha  \
# 0  65fb1650b5171ca17cd7231f                 7759  201803161337187
# 1  65fb1650b5171ca17cd7232d                 7526  201709211148001
# 2  65fb1650b5171ca17cd72336                 7516  201709121317043
#
#                      Operador_Padronizado Classificacao_da_Ocorrência  \
# 0     EJ ESCOLA DE AERONAUTICA CIVIL LTDA                    Acidente
# 1         POLICIA MILITAR DE MINAS GERAIS                   Incidente
# 2  SOS SERV.E RECUP.DE AERONAVES LTDA-EPP                    Acidente
#
#   Data_da_Ocorrencia Hora_da_Ocorrência               Municipio  UF   Regiao  \
# 0         2018-03-14           15:30:00           MONTES CLAROS  MG  Sudeste
# 1         2017-09-20           17:40:00          BELO HORIZONTE  MG  Sudeste
# 2         2017-09-02           18:30:00  SÃO FRANCISCO DE SALES  MG  Sudeste
#
#                                    Descricao_do_Tipo               ICAO  \
# 0                                        COMBUSTÍVEL  Fora de Aeródromo
# 1  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...               None
# 2                           PERDA DE CONTROLE EM VOO               None
#
#    Latitude Longitude Tipo_de_Aerodromo  \
# 0  -16,7861  -43,8817                 -
# 1  -19,9092  -43,9892              None
# 2  -19,8628  -49,7739              None
#
#                                            Historico Matricula  \
# 0  QUANDO A AERONAVE ATINGIU 6 MILHAS AO SUL DO A...     PREJO
# 1  OS COMANDOS DA AERONAVE APRESENTARAM ENRIJECIM...     PTYAP
# 2  A AERONAVE REALIZAVA VOO A BAIXA ALTURA E COME...     PRZRR
#
#   Categoria_da_Aeronave                                Operador  \
# 0                   PRI           EJ ESCOLA DE AERONAUTICA LTDA
# 1                   ADE         POLÍCIA MILITAR DE MINAS GERAIS
# 2                   PET  SOS SERV.E RECUP.DE AERONAVES LTDA-EPP
#
#   Tipo_de_Ocorrencia    Fase_da_Operacao          Operacao Danos_a_Aeronave  \
# 0               FUEL             Em rota  Voo de Instrução      Substancial
# 1             SCF-NP             Em rota  Operação Pública           Nenhum
# 2              LOC-I  Voo a baixa altura       Voo Privado        Destruída
#
#   Aerodromo_de_Destino Aerodromo_de_Origem Lesoes_Fatais_Tripulantes  \
# 0                 SBMK                SIMK                         0
# 1                 SBPR                SBBH                         0
# 2                 SNYB                SBGO                         1
#
#   Lesoes_Fatais_Passageiros Lesoes_Fatais_Terceiros Lesoes_Graves_Tripulantes  \
# 0                         0                       0                         0
# 1                         0                       0                         0
# 2                         0                       0                         0
#
#   Lesoes_Graves_Passageiros Lesoes_Graves_Terceiros Lesoes_Leves_Tripulantes  \
# 0                         0                       0                        0
# 1                         0                       0                        0
# 2                         0                       0                        0
#
#   Lesoes_Leves_Passageiros Lesoes_Leves_Terceiros Ilesos_Tripulantes  \
# 0                        0                      0                  1
# 1                        0                      0                  2
# 2                        0                      0                  0
#
#   Ilesos_Passageiros Lesoes_Desconhecidas_Tripulantes  \
# 0                  1                                0
# 1                  0                                0
# 2                  0                                0
#
#   Lesoes_Desconhecidas_Passageiros Lesoes_Desconhecidas_Terceiros  \
# 0                                0                              0
# 1                                0                              0
# 2                                0                              0
#
#               Modelo  CLS Tipo_ICAO   PMD Numero_de_Assentos  \
# 0               A152  L1P      C152   757                  2
# 1               206B  H1T       B06  1451                  5
# 2  300LS HUMMINGBIRD  H1P      ZZZZ  1270                  4
#
#   Nome_do_Fabricante        PSSO
# 0    CESSNA AIRCRAFT  verdadeiro
# 1    BELL HELICOPTER  verdadeiro
# 2      STOCO AVIAÇÃO       falso

# %%
df.shape[0]
# Out:
# 1041
