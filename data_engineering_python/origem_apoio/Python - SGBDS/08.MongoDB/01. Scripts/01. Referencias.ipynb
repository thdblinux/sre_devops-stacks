# %% [markdown]
# MongoDB
#
# https://www.mongodb.com/pt-br/pricing
#
# DB-Engines Ranking ranks databas
#
# https://db-engines.com/en/ranking
#
# IBGE
#
# https://servicodados.ibge.gov.br/api/docs/localidades#api-Microrregioes-estadosUFMicrorregioesGet

# %% [markdown]
# pesquisa no Google =comparaçao estrutura sql e mongo db
#
# ![image.png](attachment:image.png)

# %% [markdown]
# MongoDB community
#
# https://www.mongodb.com/try/download/community
#
#
# MongoDB Compass Download e Documentação
#
# https://www.mongodb.com/docs/compass/current/
