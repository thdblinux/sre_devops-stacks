# %%
import requests
import pandas as pd
from pymongo import MongoClient
pd.set_option('display.max_columns', None)   # Mostrar todas as colunas

url = "https://servicodados.ibge.gov.br/api/v1/localidades/distritos"
response = requests.get(url)
data = response.json()

#Mapeamento de destino
client = MongoClient('mongodb+srv://user_aula:Aula.12345@clusteraula.ubzchn7.mongodb.net/')
db = client['IBGE']
#colletion= db.get_collection('distritos')
collection= db['distritos']

#delete antes da carga
collection.delete_many({})

#enviando dados para MongoDB
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('66015cf29bd31b403c7f9e00'), ObjectId('66015cf29bd31b403c7f9e01'), ObjectId('66015cf29bd31b403c7f9e02'), ObjectId('66015cf29bd31b403c7f9e03'), ObjectId('66015cf29bd31b403c7f9e04'), ObjectId('66015cf29bd31b403c7f9e05'), ObjectId('66015cf29bd31b403c7f9e06'), ObjectId('66015cf29bd31b403c7f9e07'), ObjectId('66015cf29bd31b403c7f9e08'), ObjectId('66015cf29bd31b403c7f9e09'), ObjectId('66015cf29bd31b403c7f9e0a'), ObjectId('66015cf29bd31b403c7f9e0b'), ObjectId('66015cf29bd31b403c7f9e0c'), ObjectId('66015cf29bd31b403c7f9e0d'), ObjectId('66015cf29bd31b403c7f9e0e'), ObjectId('66015cf29bd31b403c7f9e0f'), ObjectId('66015cf29bd31b403c7f9e10'), ObjectId('66015cf29bd31b403c7f9e11'), ObjectId('66015cf29bd31b403c7f9e12'), ObjectId('66015cf29bd31b403c7f9e13'), ObjectId('66015cf29bd31b403c7f9e14'), ObjectId('66015cf29bd31b403c7f9e15'), ObjectId('66015cf29bd31b403c7f9e16'), ObjectId('66015cf29bd31b403c7f9e17'), ObjectId('66015cf29bd31b403c7f9e18'), ObjectId('66015cf29bd31b403c7f
# ...
