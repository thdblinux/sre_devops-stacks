# %%
import requests
import pandas as pd

url = f"https://servicodados.ibge.gov.br/api/v1/localidades/municipios/1302553|1302702|1302801|1504422|1504455|1504505|1506583|1506609"
response = requests.get(url).json()

df = pd.json_normalize(response) # transformando resultado em DF 
df.head()
# Out:
#         id          nome  microrregiao.id microrregiao.nome  \
# 0  1302553     Manaquiri            13007            Manaus
# 1  1302702      Manicoré            13013           Madeira
# 2  1302801         Maraã            13002            Japurá
# 3  1504422      Marituba            15007             Belém
# 4  1504455  Medicilândia            15015          Altamira
#
#    microrregiao.mesorregiao.id microrregiao.mesorregiao.nome  \
# 0                         1303             Centro Amazonense
# 1                         1304                Sul Amazonense
# 2                         1301              Norte Amazonense
# 3                         1503        Metropolitana de Belém
# 4                         1505             Sudoeste Paraense
#
#    microrregiao.mesorregiao.UF.id microrregiao.mesorregiao.UF.sigla  \
# 0                              13                                AM
# 1                              13                                AM
# ...
